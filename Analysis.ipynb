# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('rev_data.csv')

# %%
df
# Out:
#        Unnamed: 0 state_entry       term                    school_name  \
# 0               0     Alabama  Fall 2021  Alabama Agric Mech University
# 1               1     Alabama  Fall 2021  Alabama Agric Mech University
# 2               2     Alabama  Fall 2021  Alabama Agric Mech University
# 3               3     Alabama  Fall 2021  Alabama Agric Mech University
# 4               4     Alabama  Fall 2021  Alabama Agric Mech University
# ...           ...         ...        ...                            ...
# 82545       82545     Wyoming  Fall 2021    Westrn Wyoming Cmty College
# 82546       82546     Wyoming  Fall 2021    Westrn Wyoming Cmty College
# 82547       82547     Wyoming  Fall 2021    Westrn Wyoming Cmty College
# 82548       82548     Wyoming  Fall 2021    Westrn Wyoming Cmty College
# 82549       82549     Wyoming  Fall 2021    Westrn Wyoming Cmty College
#
#           t_class                     t_title        t_level t_mingrade  \
# ...

# %%
pd.set_option("display.max_rows", None)

df.loc[df['gt_class'] == 'MATH  2551']
# Out:
#        Unnamed: 0     state_entry       term                     school_name  \
# 542           542         Alabama  Fall 2021   Bevill State Cmty Coll Brewer
# 1000         1000         Alabama  Fall 2021      Jacksonville St University
# 1226         1226         Alabama  Fall 2021              Samford University
# 1316         1316         Alabama  Fall 2021   Snead State Community College
# 1744         1744         Alabama  Fall 2021         Univ Alabama Birmingham
# 1851         1851         Alabama  Fall 2021         Univ Alabama Huntsville
# 2010         2010         Alabama  Fall 2021        Univ Alabama Tuscaloosa*
# 2014         2014         Alabama  Fall 2021        Univ Alabama Tuscaloosa*
# 2268         2268          Alaska  Fall 2021           Univ Alaska Anchorage
# 2616         2616         Arizona  Fall 2021        Arizona State University
# 2779         2779         Arizona  Fall 2021   Chandler Gilbert Cmty College
# ...
